# %% [markdown]
# # Algorithmics Trading Using LSTM Long Strategy

# %% [markdown]
# ## Import Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import datetime
from datetime import date

import yfinance as yf
import pyfolio as pf

import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

np.random.seed(10)

# %%
data = yf.download('MSFT')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061109
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063292
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064383
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062746
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061655
# ...                ...         ...         ...         ...         ...
# 2022-06-06  272.059998  274.179993  267.220001  268.750000  268.750000
# 2022-06-07  266.640015  273.130005  265.940002  272.500000  272.500000
# 2022-06-08  271.709991  273.000000  269.609985  270.410004  270.410004
# 2022-06-09  267.779999  272.709991  264.630005  264.790009  264.790009
# 2022-06-10  260.579987  260.540009  253.949997  254.520004  254.520004
#
#                 Volume
# Date
# 1986-03-13  1031788800
# 1986-03-14   308160000
# 1986-03-17   133171200
# 1986-03-18    67766400
# 1986-03-19    47894400
# ...                ...
# 2022-06-06    22400300
# 2022-06-07    22860700
# 2022-06-08    17372300
# 2022-06-09    26425500
# 2022-06-10    15556422
#
# [9137 rows x 6 columns]

# %%
data['Adj Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Compute Returns and Define Target

# %%
data['returns'] = data['Adj Close'].pct_change()
data['target'] = np.where(data['returns'].shift(-1) > 0, 1, 0)

# %% [markdown]
# ## Scale the Data by Rolling Min-Max Method

# %%
data2 = data.copy()

p=21*2
data2['min'] = data2['Low'].rolling(p).min()
data2['max'] = data2['High'].rolling(p).max()
data2.dropna(inplace=True)

data2['Open'] = (data2['Open']-data2['min'])/(data2['max']-data2['min'])
data2['High'] = (data2['High']-data2['min'])/(data2['max']-data2['min'])
data2['Low'] = (data2['Low']-data2['min'])/(data2['max']-data2['min'])
data2['Close'] = (data2['Close']-data2['min'])/(data2['max']-data2['min'])
data2['Adj Close'] = (data2['Adj Close']-data2['min'])/(data2['max']-data2['min'])
data2.dropna(inplace=True)
data2
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 1986-05-12  0.649342  0.753232  0.649342  0.675314  -0.559624  10483200
# 1986-05-13  0.666656  0.719986  0.666656  0.693321  -0.584450   3830400
# 1986-05-14  0.693321  0.693321  0.666656  0.666656  -0.601211   9302400
# 1986-05-15  0.666656  0.719986  0.666656  0.666656  -0.601211   3801600
# 1986-05-16  0.666656  0.773316  0.666656  0.693321  -0.584450  11952000
# ...              ...       ...       ...       ...        ...       ...
# 2022-06-06  0.423051  0.458058  0.343131  0.368395   0.368395  22400300
# 2022-06-07  0.353085  0.466527  0.340850  0.455515   0.455515  22860700
# 2022-06-08  0.462143  0.485735  0.423738  0.438369   0.438369  17372300
# 2022-06-09  0.455399  0.560606  0.388178  0.391592   0.391592  26425500
# 2022-06-10  0.301750  0.300897  0.160265  0.172429   0.172429  15556422
#
#              returns  target         min         max
# Date
# 1986-05-12  0.007874       1    0.088542    0.121962
# 1986-05-13  0.007812       0    0.089410    0.121962
# 1986-05-14 -0.007752       0    0.089410    0.121962
# 1986-05-15  0.000000       1    0.089410    0.121962
# 1986-05-16  0.007812       0    0.089410    0.121962
# ...              ...     ...         ...         ...
# 2022-06-06 -0.004703       1  246.440002  307.000000
# 2022-06-07  0.013953       0  246.440002  303.649994
# 2022-06-08 -0.007670       0  246.440002  301.119995
# 2022-06-09 -0.020783       0  246.440002  293.299988
# 2022-06-10 -0.038785       0  246.440002  293.299988
#
# [9096 rows x 10 columns]

# %% [markdown]
# Adj Close is showing NEGATIVE values

# %%
data2['target'].value_counts()
# Out:
# 1    4598
# 0    4498
# Name: target, dtype: int64

# %% [markdown]
# ## Create X-y Pair for LSTM

# %%
def sliding_window(data, timesteps):
    x = []
    y = []

    for i in range(len(data)-timesteps):
        _x = data.iloc[i:(i+timesteps)][['Open','High','Low','Adj Close']]
        _y = data.iloc[i+timesteps-1]['target']
    
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %%
timesteps = 20
X,y = sliding_window(data2, timesteps)

# %%
X.shape,y.shape
# Out:
# ((9076, 20, 4), (9076,))

# %% [markdown]
# ## Train-Test Data Split

# %%
# Total dataset length
dataset_length = X.shape[0]

# Training dataset length
split = int(dataset_length * 0.7)
split
# Out:
# 6353

# %%
# Splitiing the X and y into train and test datasets
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Print the size of the train and test dataset
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (6353, 20, 4) (2723, 20, 4)
# (6353,) (2723,)

# %% [markdown]
# ## Define the Model

# %%
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM,Dense

# feature = X_train.shape[2]
# hidden_size = 5

# model = Sequential()
# model.add(LSTM(hidden_size,input_shape=(timesteps,feature)))
# model.add(Dense(1, activation='sigmoid'))

# %%
#Stacked LSTM Moddel

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

feature = X_train.shape[2]
hidden_size = 5

model = Sequential()
model.add(LSTM(hidden_size,return_sequences=True,input_shape=(timesteps,feature)))
model.add(LSTM(hidden_size,return_sequences=True))
model.add(LSTM(hidden_size))
model.add(Dense(1, activation='sigmoid'))

# %%
# Bidirectional LSTM model 

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM,Dense,Bidirectional

# feature = X_train.shape[2]
# hidden_size = 5

# model = Sequential()
# model.add(Bidirectional(LSTM(hidden_size,input_shape=(timesteps,feature))))
# model.add(Dense(1, activation='sigmoid'))

# %%
# Bidirectional Stacked LSTM model 

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM,Dense,Bidirectional

# feature = X_train.shape[2]
# hidden_size = 5

# model = Sequential()
# model.add(Bidirectional(LSTM(hidden_size,return_sequences=True,input_shape=(timesteps,feature))))
# model.add(Bidirectional(LSTM(hidden_size)))
# model.add(Dense(1, activation='sigmoid'))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## Train the Model

# %%
history = model.fit(X_train, y_train, epochs=300,batch_size=32)
# Out:
# Epoch 1/300
# 199/199 [==============================] - 6s 15ms/step - loss: 0.6973 - accuracy: 0.5028
# Epoch 2/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6968 - accuracy: 0.5028
# Epoch 3/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6964 - accuracy: 0.5028
# Epoch 4/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6960 - accuracy: 0.5028
# Epoch 5/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6956 - accuracy: 0.5028
# Epoch 6/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6953 - accuracy: 0.5028
# Epoch 7/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6950 - accuracy: 0.5028
# Epoch 8/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6948 - accuracy: 0.5028
# Epoch 9/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6946 - accuracy: 0.5028
# Epoch 10/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6945 - accuracy: 0.5023
# Epoch 11/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6943 - accuracy: 0.5026
# Epoch 12/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6942 - accuracy: 0.5028
# Epoch 13/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6940 - accuracy: 0.5021
# Epoch 14/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6939 - accuracy: 0.5029
# Epoch 15/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6938 - accuracy: 0.5028
# Epoch 16/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6938 - accuracy: 0.5029
# Epoch 17/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6937 - accuracy: 0.5009
# Epoch 18/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6936 - accuracy: 0.5023
# Epoch 19/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6936 - accuracy: 0.5021
# Epoch 20/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6935 - accuracy: 0.5026
# Epoch 21/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6935 - accuracy: 0.5031
# Epoch 22/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6934 - accuracy: 0.4999
# Epoch 23/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6934 - accuracy: 0.5006
# Epoch 24/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6934 - accuracy: 0.5029
# Epoch 25/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6933 - accuracy: 0.5020
# Epoch 26/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6933 - accuracy: 0.5013
# Epoch 27/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6933 - accuracy: 0.5021
# Epoch 28/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6933 - accuracy: 0.5028
# Epoch 29/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6933 - accuracy: 0.5028
# Epoch 30/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6933 - accuracy: 0.5045
# Epoch 31/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5037
# Epoch 32/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5035
# Epoch 33/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5031
# Epoch 34/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5032
# Epoch 35/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5039
# Epoch 36/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5053
# Epoch 37/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5065
# Epoch 38/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5070
# Epoch 39/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5062
# Epoch 40/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5061
# Epoch 41/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5083
# Epoch 42/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5084
# Epoch 43/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6932 - accuracy: 0.5087
# Epoch 44/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5075
# Epoch 45/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5079
# Epoch 46/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5076
# Epoch 47/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6932 - accuracy: 0.5067
# Epoch 48/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 49/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 50/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 51/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 52/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 53/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 54/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5061
# Epoch 55/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 56/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 57/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 58/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 59/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 60/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 61/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5094
# Epoch 62/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5098
# Epoch 63/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 64/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 65/300
# 199/199 [==============================] - 3s 15ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 66/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 67/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 68/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 69/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 70/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 71/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 72/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 73/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 74/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 75/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 76/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 77/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 78/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 79/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 80/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 81/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 82/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 83/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 84/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 85/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 86/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 87/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 88/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 89/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 90/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 91/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 92/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 93/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5103
# Epoch 94/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 95/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 96/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 97/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 98/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 99/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 100/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 101/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 102/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 103/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 104/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 105/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 106/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 107/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 108/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5094
# Epoch 109/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 110/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 111/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 112/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 113/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 114/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 115/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 116/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 117/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 118/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 119/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 120/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 121/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 122/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 123/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 124/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 125/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 126/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 127/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 128/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 129/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 130/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 131/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 132/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 133/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 134/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 135/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 136/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 137/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 138/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 139/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 140/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 141/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 142/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 143/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 144/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 145/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 146/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 147/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 148/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 149/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 150/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 151/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 152/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 153/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 154/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 155/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 156/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 157/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5051
# Epoch 158/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 159/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 160/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 161/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 162/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 163/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 164/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 165/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 166/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 167/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 168/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 169/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 170/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 171/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 172/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 173/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 174/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 175/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 176/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 177/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 178/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 179/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 180/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 181/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 182/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 183/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5053
# Epoch 184/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5050
# Epoch 185/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 186/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 187/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 188/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 189/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 190/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 191/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 192/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 193/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 194/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 195/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 196/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5053
# Epoch 197/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 198/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5061
# Epoch 199/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 200/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5061
# Epoch 201/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5053
# Epoch 202/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 203/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 204/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5062
# Epoch 205/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 206/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 207/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 208/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 209/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 210/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 211/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 212/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5050
# Epoch 213/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5053
# Epoch 214/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 215/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 216/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 217/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5057
# Epoch 218/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 219/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 220/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5059
# Epoch 221/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 222/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5065
# Epoch 223/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 224/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 225/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 226/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 227/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 228/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 229/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 230/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5067
# Epoch 231/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 232/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5087
# Epoch 233/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 234/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 235/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 236/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 237/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 238/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 239/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5070
# Epoch 240/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5087
# Epoch 241/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 242/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 243/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 244/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 245/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 246/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 247/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5054
# Epoch 248/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5056
# Epoch 249/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 250/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 251/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 252/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 253/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 254/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 255/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 256/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 257/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 258/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 259/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 260/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 261/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 262/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5068
# Epoch 263/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 264/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 265/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5072
# Epoch 266/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 267/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 268/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 269/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 270/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 271/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 272/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 273/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 274/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 275/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 276/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 277/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 278/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 279/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 280/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5075
# Epoch 281/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 282/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 283/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 284/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5076
# Epoch 285/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5094
# Epoch 286/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5086
# Epoch 287/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5073
# Epoch 288/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5092
# Epoch 289/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5084
# Epoch 290/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5083
# Epoch 291/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5081
# Epoch 292/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 293/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5089
# Epoch 294/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5078
# Epoch 295/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 296/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5091
# Epoch 297/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5079
# Epoch 298/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5094
# Epoch 299/300
# 199/199 [==============================] - 3s 13ms/step - loss: 0.6931 - accuracy: 0.5092
# Epoch 300/300
# 199/199 [==============================] - 3s 14ms/step - loss: 0.6931 - accuracy: 0.5084

# %% [markdown]
# ## Evaluate the Model

# %%
loss = history.history['loss']
epoch = range(len(loss))

import matplotlib.pyplot as plt

plt.plot(epoch,loss)
plt.xlabel('Epoch')
plt.ylabel('Loss]')
plt.show()

# %%
loss, acc = model.evaluate(X_test,y_test)
print(f"Accuracy of the model = {np.round(acc*100,2)}%")
# Out:
# 86/86 [==============================] - 1s 3ms/step - loss: 0.6922 - accuracy: 0.5244
# Accuracy of the model = 52.44%

# %%
y_pred = np.where(model.predict(X_test)>0.5,1,0)

# %%
#[print(x) for x in y_pred]

# %%
sum(y_test==0), sum(y_pred==0)
# Out:
# (1292, array([487]))

# %%
sum(y_test==1), sum(y_pred==1)
# Out:
# (1431, array([2236]))

# %%
from sklearn.metrics import confusion_matrix
matrix_confusion = confusion_matrix(y_test, y_pred)
import seaborn as sns 
sns.heatmap(matrix_confusion, square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
# Out:
# <AxesSubplot:>

# %%
# Run the code to view the classification report metrics
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.19      0.27      1292
#          1.0       0.53      0.83      0.65      1431
#
#     accuracy                           0.52      2723
#    macro avg       0.51      0.51      0.46      2723
# weighted avg       0.51      0.52      0.47      2723

# %%
data.shape, X.shape
# Out:
# ((9137, 8), (9076, 20, 4))

# %% [markdown]
# ## Trade Analytics

# %%
offset = len(data)-len(X)
data.drop(data.index[:offset], axis=0, inplace=True)
data['signal'] = np.where(model.predict(X)>0.5,1,0)
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-06-10    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-11    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-12    0.113715    0.113715    0.108507    0.109375    0.068748
# 1986-06-13    0.109375    0.110243    0.108507    0.109375    0.068748
# 1986-06-16    0.109375    0.110243    0.107639    0.108507    0.068203
# ...                ...         ...         ...         ...         ...
# 2022-06-06  272.059998  274.179993  267.220001  268.750000  268.750000
# 2022-06-07  266.640015  273.130005  265.940002  272.500000  272.500000
# 2022-06-08  271.709991  273.000000  269.609985  270.410004  270.410004
# 2022-06-09  267.779999  272.709991  264.630005  264.790009  264.790009
# 2022-06-10  260.579987  260.540009  253.949997  254.520004  254.520004
#
#               Volume   returns  target  signal
# Date
# 1986-06-10   3427200  0.000000       0       1
# 1986-06-11   2304000  0.000000       0       1
# 1986-06-12  13708800 -0.038165       0       1
# 1986-06-13   7891200  0.000000       0       1
# 1986-06-16   9590400 -0.007936       1       1
# ...              ...       ...     ...     ...
# 2022-06-06  22400300 -0.004703       1       1
# 2022-06-07  22860700  0.013953       0       1
# 2022-06-08  17372300 -0.007670       0       1
# 2022-06-09  26425500 -0.020783       0       1
# 2022-06-10  15556422 -0.038785       0       1
#
# [9076 rows x 9 columns]

# %%
data['strategy_returns'] = data['returns'].shift(-1) * data['signal']

# Drop the missing values
data.dropna(inplace=True)
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-06-10    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-11    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-12    0.113715    0.113715    0.108507    0.109375    0.068748
# 1986-06-13    0.109375    0.110243    0.108507    0.109375    0.068748
# 1986-06-16    0.109375    0.110243    0.107639    0.108507    0.068203
# ...                ...         ...         ...         ...         ...
# 2022-06-03  270.309998  273.450012  268.410004  270.019989  270.019989
# 2022-06-06  272.059998  274.179993  267.220001  268.750000  268.750000
# 2022-06-07  266.640015  273.130005  265.940002  272.500000  272.500000
# 2022-06-08  271.709991  273.000000  269.609985  270.410004  270.410004
# 2022-06-09  267.779999  272.709991  264.630005  264.790009  264.790009
#
#               Volume   returns  target  signal  strategy_returns
# Date
# 1986-06-10   3427200  0.000000       0       1          0.000000
# 1986-06-11   2304000  0.000000       0       1         -0.038165
# 1986-06-12  13708800 -0.038165       0       1          0.000000
# 1986-06-13   7891200  0.000000       0       1         -0.007936
# 1986-06-16   9590400 -0.007936       1       1          0.015999
# ...              ...       ...     ...     ...               ...
# 2022-06-03  28048000 -0.016607       0       1         -0.004703
# 2022-06-06  22400300 -0.004703       1       1          0.013953
# 2022-06-07  22860700  0.013953       0       1         -0.007670
# 2022-06-08  17372300 -0.007670       0       1         -0.020783
# 2022-06-09  26425500 -0.020783       0       1         -0.038785
#
# [9075 rows x 10 columns]

# %%
data['trade'] = data['signal'] - data['signal'].shift(1)
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-06-10    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-11    0.113715    0.113715    0.111979    0.113715    0.071476
# 1986-06-12    0.113715    0.113715    0.108507    0.109375    0.068748
# 1986-06-13    0.109375    0.110243    0.108507    0.109375    0.068748
# 1986-06-16    0.109375    0.110243    0.107639    0.108507    0.068203
# ...                ...         ...         ...         ...         ...
# 2022-06-03  270.309998  273.450012  268.410004  270.019989  270.019989
# 2022-06-06  272.059998  274.179993  267.220001  268.750000  268.750000
# 2022-06-07  266.640015  273.130005  265.940002  272.500000  272.500000
# 2022-06-08  271.709991  273.000000  269.609985  270.410004  270.410004
# 2022-06-09  267.779999  272.709991  264.630005  264.790009  264.790009
#
#               Volume   returns  target  signal  strategy_returns  trade
# Date
# 1986-06-10   3427200  0.000000       0       1          0.000000    NaN
# 1986-06-11   2304000  0.000000       0       1         -0.038165    0.0
# 1986-06-12  13708800 -0.038165       0       1          0.000000    0.0
# 1986-06-13   7891200  0.000000       0       1         -0.007936    0.0
# 1986-06-16   9590400 -0.007936       1       1          0.015999    0.0
# ...              ...       ...     ...     ...               ...    ...
# 2022-06-03  28048000 -0.016607       0       1         -0.004703    0.0
# 2022-06-06  22400300 -0.004703       1       1          0.013953    0.0
# 2022-06-07  22860700  0.013953       0       1         -0.007670    0.0
# 2022-06-08  17372300 -0.007670       0       1         -0.020783    0.0
# 2022-06-09  26425500 -0.020783       0       1         -0.038785    0.0
#
# [9075 rows x 11 columns]

# %%
data['trade'].value_counts()
# Out:
#  0.0    8968
# -1.0      53
#  1.0      53
# Name: trade, dtype: int64

# %% [markdown]
# ## Equity Curve

# %%
import matplotlib.pyplot as plt
data.strategy_returns[split:].hist()
plt.xlabel('Strategy returns (%)')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 12, 6
plt.grid(True, alpha = .3)
plt.plot(data.iloc[split:]['Adj Close'], label = 'Adj Close')
plt.plot(data[split:].loc[data.trade == 1].index, data[split:]['Adj Close'][data.trade == 1], '^', color = 'g', markersize = 8,label='buy')
plt.plot(data[split:].loc[data.trade == -1].index, data[split:]['Adj Close'][data.trade == -1], 'v',color = 'r', markersize = 8,label='sell')
plt.legend()

# %%
(data.strategy_returns[split:]+1).cumprod().plot(label='strategy return')
(data.returns[split:]+1).cumprod().plot(label='bnh return')
plt.legend()

# %%
pf.create_simple_tear_sheet(data.strategy_returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1986-06-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-06-09</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>432</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>10.6%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>3674.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.4%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-57.2%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.77</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>39.25</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.save('lstm.h5')

# %%
model2 = tf.keras.models.load_model('lstm.h5')
