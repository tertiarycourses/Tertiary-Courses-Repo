# %% [markdown]
# # Moving Average (MA) Model

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.tsa.api as smtsa

# %%
# Function to plot signal, ACF and PACF
def plotds(xt, nlag=30, fig_size=(12, 10)):
    if not isinstance(xt, pd.Series):
         xt = pd.Series(xt)
    plt.figure(figsize=fig_size)
    layout = (2, 2)
    
    # Assign axes
    ax_xt = plt.subplot2grid(layout, (0, 0), colspan=2)
    ax_acf= plt.subplot2grid(layout, (1, 0))
    ax_pacf = plt.subplot2grid(layout, (1, 1))
    
    # Plot graphs
    xt.plot(ax=ax_xt)
    ax_xt.set_title('Time Series')
    plot_acf(xt, lags=50, ax=ax_acf)
    plot_pacf(xt, lags=50, ax=ax_pacf)
    plt.tight_layout()
    return None

# %% [markdown]
# ## MA(1) Model

# %%
# Simulate AR(1) data

ar = np.array([1, 0])
ma = np.array([1,0.6])
data = smtsa.arma_generate_sample(ar,ma,1000) 
plotds(data)
# Out:
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
# Build MA(1) model
model = ARIMA(data, order=(0, 0, 1))

## Fitting the model, disp=0 is to switch off verbose display
trained_model = model.fit()

## Printing a summary of the model
trained_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(0, 0, 1)   Log Likelihood               -1407.450
# Date:                Fri, 24 Jun 2022   AIC                           2820.899
# Time:                        20:47:04   BIC                           2835.623
# Sample:                             0   HQIC                          2826.495
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0114      0.048     -0.236      0.813      -0.106       0.083
# ma.L1          0.5420      0.027     20.273      0.000       0.490       0.594
# sigma2         0.9769      0.045     21.859      0.000       0.889       1.065
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):                 1.72
# Prob(Q):                              0.66   Prob(JB):                         0.42
# Heteroskedasticity (H):               1.09   Skew:                             0.09
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## MA(2) Model

# %%
# Simulate AR(2) data

ar = np.array([1, 0])
ma = np.array([1,0.6,0.7])
data = smtsa.arma_generate_sample(ar,ma,1000) 
plotds(data)
# Out:
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
# Build MA(2) model
model = ARIMA(data, order=(0, 0, 2))

## Fitting the model, disp=0 is to switch off verbose display
trained_model = model.fit()

## Printing a summary of the model
trained_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(0, 0, 2)   Log Likelihood               -1375.751
# Date:                Fri, 24 Jun 2022   AIC                           2759.502
# Time:                        20:48:10   BIC                           2779.133
# Sample:                             0   HQIC                          2766.963
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0875      0.071      1.234      0.217      -0.052       0.227
# ma.L1          0.6257      0.023     27.453      0.000       0.581       0.670
# ma.L2          0.7159      0.022     32.385      0.000       0.673       0.759
# sigma2         0.9158      0.040     22.876      0.000       0.837       0.994
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.67
# Prob(Q):                              0.78   Prob(JB):                         0.72
# Heteroskedasticity (H):               1.20   Skew:                            -0.03
# Prob(H) (two-sided):                  0.10   Kurtosis:                         3.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## MA(3) Model

# %%
# Simulate MA(3) data

ar = np.array([1, 0])
ma = np.array([1,0.6,0.7,-0.5])
data = smtsa.arma_generate_sample(ar,ma,1000) 
plotds(data)
# Out:
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
# Build MA(3) model
model = ARIMA(data, order=(0, 0, 3))

## Fitting the model, disp=0 is to switch off verbose display
trained_model = model.fit()

## Printing a summary of the model
trained_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                 ARIMA(0, 0, 3)   Log Likelihood               -1585.543
# Date:                Fri, 24 Jun 2022   AIC                           3181.086
# Time:                        20:49:16   BIC                           3205.624
# Sample:                             0   HQIC                          3190.412
#                                - 1000
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0896      0.055      1.637      0.102      -0.018       0.197
# ma.L1          0.4527      0.029     15.440      0.000       0.395       0.510
# ma.L2          0.4337      0.028     15.273      0.000       0.378       0.489
# ma.L3         -0.4228      0.030    -14.230      0.000      -0.481      -0.365
# sigma2         1.3919      0.067     20.841      0.000       1.261       1.523
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 2.67
# Prob(Q):                              0.81   Prob(JB):                         0.26
# Heteroskedasticity (H):               0.94   Skew:                            -0.04
# Prob(H) (two-sided):                  0.56   Kurtosis:                         2.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## MA Forecasting on Stock Data

# %%
import yfinance as yf

data = yf.download('Z74.SI', start = '2020-06-01')

plotds(data['Adj Close'].values)
# Out:
# [*********************100%***********************]  1 of 1 completed
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
data['sma'] = data['Adj Close'].rolling(15).mean()
data[['Adj Close','sma']].plot(lw=2,figsize=(12,8));

# %%
model = ARIMA(data['Adj Close'], order=(0, 0, 10))
trained_model = model.fit()
trained_model.summary()
# Out:
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/alfred/opt/anaconda3/envs/py37/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                  522
# Model:                ARIMA(0, 0, 10)   Log Likelihood                1079.605
# Date:                Fri, 24 Jun 2022   AIC                          -2135.209
# Time:                        21:08:39   BIC                          -2084.117
# Sample:                             0   HQIC                         -2115.198
#                                 - 522
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3638      0.016    144.343      0.000       2.332       2.396
# ma.L1          1.2687      0.041     31.193      0.000       1.189       1.348
# ma.L2          1.3907      0.062     22.339      0.000       1.269       1.513
# ma.L3          1.4047      0.074     18.995      0.000       1.260       1.550
# ma.L4          1.4707      0.086     17.027      0.000       1.301       1.640
# ma.L5          1.3829      0.095     14.606      0.000       1.197       1.568
# ma.L6          1.2893      0.098     13.132      0.000       1.097       1.482
# ma.L7          1.0889      0.094     11.632      0.000       0.905       1.272
# ma.L8          0.8367      0.087      9.664      0.000       0.667       1.006
# ma.L9          0.5461      0.073      7.520      0.000       0.404       0.688
# ma.L10         0.2750      0.048      5.775      0.000       0.182       0.368
# sigma2         0.0009   4.94e-05     18.801      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):                28.01
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.02   Skew:                             0.25
# Prob(H) (two-sided):                  0.88   Kurtosis:                         4.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start_date = '2020-06-01'
end_date   = '2022-06-20'
data['forecast'] = trained_model.predict(start=start_date, end=end_date)

# %%
data[['Adj Close','sma','forecast']].tail(10)
# Out:
#             Adj Close       sma  forecast
# Date
# 2022-06-13       2.54  2.602000  2.525309
# 2022-06-14       2.52  2.593333  2.524990
# 2022-06-15       2.50  2.584000  2.489576
# 2022-06-16       2.47  2.566667  2.458052
# 2022-06-17       2.47  2.551333  2.445536
# 2022-06-20       2.50  2.541333  2.455403
# 2022-06-21       2.55  2.538667       NaN
# 2022-06-22       2.52  2.533333       NaN
# 2022-06-23       2.53  2.529333       NaN
# 2022-06-24       2.58  2.529333       NaN

# %%
data[['Adj Close','sma','forecast']].plot(lw=2,figsize=(12,8));
